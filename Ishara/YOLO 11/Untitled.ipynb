# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_56252\2596219500.py in <module>
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolov11n.pt")
#       4
#       5 model.train(
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.156-py3-none-any.whl (1.0 MB)
# ...
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# ...
#   Using cached ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
#   Using cached torch-2.3.0-cp39-cp39-win_amd64.whl (159.7 MB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
# ...
#   Using cached intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
# ...
#   Using cached tbb-2021.13.1-py3-none-win_amd64.whl (286 kB)
# ...
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# WARNING: Ignoring invalid distribution -cipy (c:\users\ishar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\ishar\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\ishar\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -cipy (c:\users\ishar\anaconda3\lib\site-packages)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

model.train(
    data = "Trees-1/data.yaml",
    epochs = 50,
    batch = 8,
    imgsz = 640,
   
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_56252\2320561342.py in <module>
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("yolo11n.pt")
#       4
#       5 model.train(
#
# ModuleNotFoundError: No module named 'ultralytics'
